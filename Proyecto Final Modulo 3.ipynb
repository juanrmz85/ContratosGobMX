# %% [markdown]
# Checkpoint para el Alumno
# # **Modulo 3: Procesamiento de Datos con Python**

# %% [markdown]
# **Introducción:**
#
# El artículo 134 de la Constitución Política de los Estados Unidos Mexicanos establece que los recursos económicos de que dispongan la Federación, las entidades federativas,
# los Municipios y las demarcaciones territoriales de la Ciudad de México, se administrarán con eficiencia,
# eficacia, economía, transparencia y honradez para satisfacer los objetivos a los que estén destinados.
#
# Así mismo establece que las adquisiciones, arrendamientos y enajenaciones de todo tipo de bienes, prestación de servicios de
# cualquier naturaleza y la contratación de obra que realicen, se adjudicarán o llevarán a cabo a través de
# licitaciones públicas mediante convocatoria pública para que libremente se presenten proposiciones
# solventes en sobre cerrado, que será abierto públicamente, a fin de asegurar al Estado las mejores
# condiciones disponibles en cuanto a precio, calidad, financiamiento, oportunidad y demás circunstancias
# pertinentes.
#
# Conociendo esto, en el siguiente proyecto haremos el análisis de una base de datos del Gobierno de México de los contratos derivados de los procedimientos de contratación reportados en CompraNet por las unidades compradoras en 2020.

# %% [markdown]
# **Importamos Librerias**
#
# Como punto inicial de nuestro cuaderno, importamos librerias y montamos el drive que estaremos utilizando durante el desarrollo del proyecto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Importamos Datos**
#
# En este punto necesitamos importar los datos con los cuales estareamos trabajando durante el proyecto.

# %%
contratos = pd.read_csv('/content/drive/MyDrive/Checkpoint Modulo 3/Contratos2020.csv',index_col=0)

contratos.head()
# Out:
# /tmp/ipykernel_2642/3782819030.py:1: DtypeWarning: Columns (6,20,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   contratos = pd.read_csv('/content/drive/MyDrive/Checkpoint Modulo 3/Contratos2020.csv',index_col=0)
#                   Siglas de la Institución  \
# Orden de gobierno
# APF                                DICONSA
# GM                                     GTO
# APF                                 SEDATU
# APF                                 SEDENA
# APF                                 SEDENA
#
#                                                          Institución  \
# Orden de gobierno
# APF                                            Diconsa, S.A. de C.V.
# GM                      _Gobierno Municipal del Estado de Guanajuato
# APF                Secretaría de Desarrollo Agrario, Territorial ...
# APF                                Secretaría de la Defensa Nacional
# APF                                Secretaría de la Defensa Nacional
#
#                   Clave de la UC  \
# Orden de gobierno
# APF                    008VSS998
# GM                     811023986
# APF                    015000999
# APF                    007000999
# APF                    007000999
#
#                                                      Nombre de la UC  \
# Orden de gobierno
# APF                           DICONSA-Dirección Comercial #008VSS998
# GM                        GTO-Pénjamo-Tesorería Municipal #811023986
# APF                SEDATU-Dirección General de Recursos Materiale...
# APF                  SEDENA-Subdirección de Adquisiciones #007000999
# APF                  SEDENA-Subdirección de Adquisiciones #007000999
#
#                           Responsable de la UC Código del expediente  \
# Orden de gobierno
# APF                José Juan Velazquez Barbosa               2163712
# GM                       Salvador Puebla Pérez               2181836
# APF                Ada Gricelda Bonifaz Villar               2173823
# APF                 Enrique Hernández Cisneros               2177310
# APF                 Enrique Hernández Cisneros               2177310
#
#                                     Referencia del expediente Clave CUCOP  \
# Orden de gobierno
# APF                                                 511/32120        2380
# GM                 MPE-CASCOS BALÍSTICOS-FORTASEG20-LR13/2020        2830
# APF                                       SEDATU-856-110-2020        3390
# APF                                    AA-007000999-E681-2020        3180
# APF                                    AA-007000999-E681-2020        3180
#
#                                           Título del expediente  \
# Orden de gobierno
# APF                                                CAFE SOLUBLE
# GM                 ADQUISICIÓN DE CASCOS BALÍSTICOS NIVEL III-A
# APF                                    PRESTACION DE SERVICIOS
# APF                     contratacion del servicio de mensajeria
# APF                     contratacion del servicio de mensajeria
#
#                                             Plantilla del expediente  ...  \
# Orden de gobierno                                                     ...
# APF                                  05. Adjudicación Directa LAASSP  ...
# GM                 03. Invitación a Cuando Menos Tres Personas LA...  ...
# APF                                  05. Adjudicación Directa LAASSP  ...
# APF                                  05. Adjudicación Directa LAASSP  ...
# APF                                  05. Adjudicación Directa LAASSP  ...
#
#                   Clave de cartera SHCP Folio en el RUPC           RFC  \
# Orden de gobierno
# APF                                 NaN              NaN           NaN
# GM                                  NaN              NaN  MTC130813PN2
# APF                                 NaN              NaN           NaN
# APF                                 NaN           8319.0  EME880309SK5
# APF                                 NaN           8319.0  EME880309SK5
#
#                                 Proveedor o contratista  \
# Orden de gobierno
# APF                         MARCAS NESTLE, S.A. DE C.V.
# GM                 MGR TEXTILES Y CONFECCIONES SA DE CV
# APF                                  MAYDE SOLÍS MÉNDEZ
# APF                          ESTAFETA MEXICANA SA DE CV
# APF                          ESTAFETA MEXICANA SA DE CV
#
#                   Estratificación de la empresa Clave del país de la empresa  \
# Orden de gobierno
# APF                                         NaN                           MX
# GM                                      Pequeña                           MX
# APF                                         NaN                           MX
# APF                                   No MIPYME                           MX
# APF                                   No MIPYME                           MX
#
#                   RFC verificado en el SAT Crédito externo  \
# Orden de gobierno
# APF                                      0             NaN
# GM                                       1             NaN
# APF                                      0             NaN
# APF                                      1             NaN
# APF                                      1             NaN
#
#                   Organismo financiero  \
# Orden de gobierno
# APF                                NaN
# GM                                 NaN
# APF                                NaN
# APF                                NaN
# APF                                NaN
#
#                                                Dirección del anuncio
# Orden de gobierno
# APF                https://compranet.hacienda.gob.mx/esop/guest/g...
# GM                 https://compranet.hacienda.gob.mx/esop/guest/g...
# APF                https://compranet.hacienda.gob.mx/esop/guest/g...
# APF                https://compranet.hacienda.gob.mx/esop/guest/g...
# APF                https://compranet.hacienda.gob.mx/esop/guest/g...
#
# [5 rows x 44 columns]

# %% [markdown]
# **Limpieza de Datos**
#
# Para poder proceder con la limpieza de nuestros datos, primero hacemos un analisis para saber el tamaño de nuestro DS, así como el tipo de datos con los cuales estaremos trabajando.

# %%
contratos.shape
# Out:
# (159726, 44)

# %%
contratos.dtypes
# Out:
# Siglas de la Institución          object
# Institución                       object
# Clave de la UC                    object
# Nombre de la UC                   object
# Responsable de la UC              object
# Código del expediente             object
# Referencia del expediente         object
# Clave CUCOP                       object
# Título del expediente             object
# Plantilla del expediente          object
# Fundamento legal                  object
# Número del procedimiento          object
# Fecha de fallo                    object
# Fecha de publicación              object
# Fecha de apertura                 object
# Carácter del procedimiento        object
# Tipo de contratación              object
# Tipo de procedimiento             object
# Forma de participación            object
# Código del contrato               object
# Núm. de control del contrato      object
# Título del contrato               object
# Descripción del contrato          object
# Fecha de inicio del contrato      object
# Fecha de fin del contrato         object
# Importe del contrato             float64
# Moneda del contrato               object
# Estatus del contrato              object
# Convenio modificatorio           float64
# Clave del programa federal        object
# Fecha de firma del contrato       object
# Contrato marco                    object
# Compra consolidada               float64
# Contrato plurianual              float64
# Clave de cartera SHCP             object
# Folio en el RUPC                 float64
# RFC                               object
# Proveedor o contratista           object
# Estratificación de la empresa     object
# Clave del país de la empresa      object
# RFC verificado en el SAT           int64
# Crédito externo                   object
# Organismo financiero              object
# Dirección del anuncio             object
# dtype: object

# %% [markdown]
# Utilizando la función info del DF, podremos ver mas información de cada columna.

# %%
contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159726 entries, APF to APF
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Siglas de la Institución       159726 non-null  object
#  1   Institución                    159726 non-null  object
#  2   Clave de la UC                 159726 non-null  object
#  3   Nombre de la UC                159726 non-null  object
#  4   Responsable de la UC           159726 non-null  object
#  5   Código del expediente          159726 non-null  object
#  6   Referencia del expediente      150396 non-null  object
#  7   Clave CUCOP                    159713 non-null  object
#  8   Título del expediente          159726 non-null  object
#  9   Plantilla del expediente       159586 non-null  object
#  10  Fundamento legal               135875 non-null  object
#  11  Número del procedimiento       159586 non-null  object
#  12  Fecha de fallo                 33458 non-null   object
#  13  Fecha de publicación           158808 non-null  object
#  14  Fecha de apertura              159141 non-null  object
#  15  Carácter del procedimiento     159156 non-null  object
#  16  Tipo de contratación           157613 non-null  object
#  17  Tipo de procedimiento          159726 non-null  object
#  18  Forma de participación         159142 non-null  object
#  19  Código del contrato            159726 non-null  object
#  20  Núm. de control del contrato   157119 non-null  object
#  21  Título del contrato            159726 non-null  object
#  22  Descripción del contrato       158827 non-null  object
#  23  Fecha de inicio del contrato   159726 non-null  object
#  24  Fecha de fin del contrato      159696 non-null  object
#  25  Importe del contrato           159726 non-null  float64
#  26  Moneda del contrato            159726 non-null  object
#  27  Estatus del contrato           159726 non-null  object
#  28  Convenio modificatorio         159699 non-null  float64
#  29  Clave del programa federal     8550 non-null    object
#  30  Fecha de firma del contrato    66141 non-null   object
#  31  Contrato marco                 150611 non-null  object
#  32  Compra consolidada             159699 non-null  float64
#  33  Contrato plurianual            159699 non-null  float64
#  34  Clave de cartera SHCP          4909 non-null    object
#  35  Folio en el RUPC               72489 non-null   float64
#  36  RFC                            101538 non-null  object
#  37  Proveedor o contratista        159726 non-null  object
#  38  Estratificación de la empresa  123998 non-null  object
#  39  Clave del país de la empresa   159726 non-null  object
#  40  RFC verificado en el SAT       159726 non-null  int64
#  41  Crédito externo                6625 non-null    object
#  42  Organismo financiero           2617 non-null    object
#  43  Dirección del anuncio          159303 non-null  object
# dtypes: float64(5), int64(1), object(38)
# memory usage: 54.8+ MB

# %% [markdown]
# Después de visualizar el conteo de los valores nulos en nuestra base de datos, haremos un conteo de los valores N/A presentes en nuestra información.

# %%
contratos.isna()
# Out:
#                    Siglas de la Institución  Institución  Clave de la UC  \
# Orden de gobierno
# APF                                   False        False           False
# GM                                    False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# ...                                     ...          ...             ...
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
#
#                    Nombre de la UC  Responsable de la UC  \
# Orden de gobierno
# APF                          False                 False
# GM                           False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# ...                            ...                   ...
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
#
#                    Código del expediente  Referencia del expediente  \
# Orden de gobierno
# APF                                False                      False
# GM                                 False                      False
# APF                                False                      False
# APF                                False                      False
# APF                                False                      False
# ...                                  ...                        ...
# APF                                False                       True
# APF                                False                       True
# APF                                False                       True
# APF                                False                       True
# APF                                False                       True
#
#                    Clave CUCOP  Título del expediente  \
# Orden de gobierno
# APF                      False                  False
# GM                       False                  False
# APF                      False                  False
# APF                      False                  False
# APF                      False                  False
# ...                        ...                    ...
# APF                      False                  False
# APF                      False                  False
# APF                      False                  False
# APF                      False                  False
# APF                      False                  False
#
#                    Plantilla del expediente  ...  Clave de cartera SHCP  \
# Orden de gobierno                            ...
# APF                                   False  ...                   True
# GM                                    False  ...                   True
# APF                                   False  ...                   True
# APF                                   False  ...                   True
# APF                                   False  ...                   True
# ...                                     ...  ...                    ...
# APF                                   False  ...                  False
# APF                                   False  ...                  False
# APF                                   False  ...                  False
# APF                                   False  ...                  False
# APF                                   False  ...                  False
#
#                    Folio en el RUPC    RFC  Proveedor o contratista  \
# Orden de gobierno
# APF                            True   True                    False
# GM                             True  False                    False
# APF                            True   True                    False
# APF                           False  False                    False
# APF                           False  False                    False
# ...                             ...    ...                      ...
# APF                            True  False                    False
# APF                            True  False                    False
# APF                            True  False                    False
# APF                            True  False                    False
# APF                            True  False                    False
#
#                    Estratificación de la empresa  \
# Orden de gobierno
# APF                                         True
# GM                                         False
# APF                                         True
# APF                                        False
# APF                                        False
# ...                                          ...
# APF                                        False
# APF                                        False
# APF                                        False
# APF                                        False
# APF                                        False
#
#                    Clave del país de la empresa  RFC verificado en el SAT  \
# Orden de gobierno
# APF                                       False                     False
# GM                                        False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# ...                                         ...                       ...
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
#
#                    Crédito externo  Organismo financiero  \
# Orden de gobierno
# APF                           True                  True
# GM                            True                  True
# APF                           True                  True
# APF                           True                  True
# APF                           True                  True
# ...                            ...                   ...
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
#
#                    Dirección del anuncio
# Orden de gobierno
# APF                                False
# GM                                 False
# APF                                False
# APF                                False
# APF                                False
# ...                                  ...
# APF                                False
# APF                                False
# APF                                False
# APF                                False
# APF                                False
#
# [159726 rows x 44 columns]

# %%
contratos.isna().sum(axis=0)
# Out:
# Siglas de la Institución              0
# Institución                           0
# Clave de la UC                        0
# Nombre de la UC                       0
# Responsable de la UC                  0
# Código del expediente                 0
# Referencia del expediente          9330
# Clave CUCOP                          13
# Título del expediente                 0
# Plantilla del expediente            140
# Fundamento legal                  23851
# Número del procedimiento            140
# Fecha de fallo                   126268
# Fecha de publicación                918
# Fecha de apertura                   585
# Carácter del procedimiento          570
# Tipo de contratación               2113
# Tipo de procedimiento                 0
# Forma de participación              584
# Código del contrato                   0
# Núm. de control del contrato       2607
# Título del contrato                   0
# Descripción del contrato            899
# Fecha de inicio del contrato          0
# Fecha de fin del contrato            30
# Importe del contrato                  0
# Moneda del contrato                   0
# Estatus del contrato                  0
# Convenio modificatorio               27
# Clave del programa federal       151176
# Fecha de firma del contrato       93585
# Contrato marco                     9115
# Compra consolidada                   27
# Contrato plurianual                  27
# Clave de cartera SHCP            154817
# Folio en el RUPC                  87237
# RFC                               58188
# Proveedor o contratista               0
# Estratificación de la empresa     35728
# Clave del país de la empresa          0
# RFC verificado en el SAT              0
# Crédito externo                  153101
# Organismo financiero             157109
# Dirección del anuncio               423
# dtype: int64

# %% [markdown]
# Para poder trabajar con un DF más reducido y que contenga únicamente los valores de mayor interés para el análisis propuesto, vamos a eliminar todas las columnas que contienen valores N/A.

# %%
contratos_clean = contratos.dropna(axis=1, how='any')

# %%
contratos_clean.isna()
# Out:
#                    Siglas de la Institución  Institución  Clave de la UC  \
# Orden de gobierno
# APF                                   False        False           False
# GM                                    False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# ...                                     ...          ...             ...
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
# APF                                   False        False           False
#
#                    Nombre de la UC  Responsable de la UC  \
# Orden de gobierno
# APF                          False                 False
# GM                           False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# ...                            ...                   ...
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
# APF                          False                 False
#
#                    Código del expediente  Título del expediente  \
# Orden de gobierno
# APF                                False                  False
# GM                                 False                  False
# APF                                False                  False
# APF                                False                  False
# APF                                False                  False
# ...                                  ...                    ...
# APF                                False                  False
# APF                                False                  False
# APF                                False                  False
# APF                                False                  False
# APF                                False                  False
#
#                    Tipo de procedimiento  Código del contrato  \
# Orden de gobierno
# APF                                False                False
# GM                                 False                False
# APF                                False                False
# APF                                False                False
# APF                                False                False
# ...                                  ...                  ...
# APF                                False                False
# APF                                False                False
# APF                                False                False
# APF                                False                False
# APF                                False                False
#
#                    Título del contrato  Fecha de inicio del contrato  \
# Orden de gobierno
# APF                              False                         False
# GM                               False                         False
# APF                              False                         False
# APF                              False                         False
# APF                              False                         False
# ...                                ...                           ...
# APF                              False                         False
# APF                              False                         False
# APF                              False                         False
# APF                              False                         False
# APF                              False                         False
#
#                    Importe del contrato  Moneda del contrato  \
# Orden de gobierno
# APF                               False                False
# GM                                False                False
# APF                               False                False
# APF                               False                False
# APF                               False                False
# ...                                 ...                  ...
# APF                               False                False
# APF                               False                False
# APF                               False                False
# APF                               False                False
# APF                               False                False
#
#                    Estatus del contrato  Proveedor o contratista  \
# Orden de gobierno
# APF                               False                    False
# GM                                False                    False
# APF                               False                    False
# APF                               False                    False
# APF                               False                    False
# ...                                 ...                      ...
# APF                               False                    False
# APF                               False                    False
# APF                               False                    False
# APF                               False                    False
# APF                               False                    False
#
#                    Clave del país de la empresa  RFC verificado en el SAT
# Orden de gobierno
# APF                                       False                     False
# GM                                        False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# ...                                         ...                       ...
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
# APF                                       False                     False
#
# [159726 rows x 17 columns]

# %%
contratos_clean.isna().sum(axis=0)
# Out:
# Siglas de la Institución        0
# Institución                     0
# Clave de la UC                  0
# Nombre de la UC                 0
# Responsable de la UC            0
# Código del expediente           0
# Título del expediente           0
# Tipo de procedimiento           0
# Código del contrato             0
# Título del contrato             0
# Fecha de inicio del contrato    0
# Importe del contrato            0
# Moneda del contrato             0
# Estatus del contrato            0
# Proveedor o contratista         0
# Clave del país de la empresa    0
# RFC verificado en el SAT        0
# dtype: int64

# %% [markdown]
# Nuestro nuevo DF quedó conformado con un total de 17 columnas y 159,726 filas.

# %%
contratos_clean.shape
# Out:
# (159726, 17)

# %%
contratos_clean.head()
# Out:
#                   Siglas de la Institución  \
# Orden de gobierno
# APF                                DICONSA
# GM                                     GTO
# APF                                 SEDATU
# APF                                 SEDENA
# APF                                 SEDENA
#
#                                                          Institución  \
# Orden de gobierno
# APF                                            Diconsa, S.A. de C.V.
# GM                      _Gobierno Municipal del Estado de Guanajuato
# APF                Secretaría de Desarrollo Agrario, Territorial ...
# APF                                Secretaría de la Defensa Nacional
# APF                                Secretaría de la Defensa Nacional
#
#                   Clave de la UC  \
# Orden de gobierno
# APF                    008VSS998
# GM                     811023986
# APF                    015000999
# APF                    007000999
# APF                    007000999
#
#                                                      Nombre de la UC  \
# Orden de gobierno
# APF                           DICONSA-Dirección Comercial #008VSS998
# GM                        GTO-Pénjamo-Tesorería Municipal #811023986
# APF                SEDATU-Dirección General de Recursos Materiale...
# APF                  SEDENA-Subdirección de Adquisiciones #007000999
# APF                  SEDENA-Subdirección de Adquisiciones #007000999
#
#                           Responsable de la UC Código del expediente  \
# Orden de gobierno
# APF                José Juan Velazquez Barbosa               2163712
# GM                       Salvador Puebla Pérez               2181836
# APF                Ada Gricelda Bonifaz Villar               2173823
# APF                 Enrique Hernández Cisneros               2177310
# APF                 Enrique Hernández Cisneros               2177310
#
#                                           Título del expediente  \
# Orden de gobierno
# APF                                                CAFE SOLUBLE
# GM                 ADQUISICIÓN DE CASCOS BALÍSTICOS NIVEL III-A
# APF                                    PRESTACION DE SERVICIOS
# APF                     contratacion del servicio de mensajeria
# APF                     contratacion del servicio de mensajeria
#
#                                   Tipo de procedimiento Código del contrato  \
# Orden de gobierno
# APF                                ADJUDICACIÓN DIRECTA             2378065
# GM                 INVITACIÓN A CUANDO MENOS 3 PERSONAS             2412672
# APF                                ADJUDICACIÓN DIRECTA             2388648
# APF                                ADJUDICACIÓN DIRECTA             2554392
# APF                                ADJUDICACIÓN DIRECTA             2628175
#
#                                             Título del contrato  \
# Orden de gobierno
# APF                                                CAFE SOLUBLE
# GM                 ADQUISICIÓN DE CASCOS BALÍSTICOS NIVEL III-A
# APF                                    PRESTACION DE SERVICIOS
# APF                     contratacion del servicio de mensajeria
# APF                     contratación del servicio de mensajería
#
#                   Fecha de inicio del contrato  Importe del contrato  \
# Orden de gobierno
# APF                                 2020-09-11              42704.50
# GM                                  2020-11-17             409655.04
# APF                                 2020-10-09              65981.33
# APF                                 2020-12-03             800000.00
# APF                                 2020-12-03             800000.00
#
#                   Moneda del contrato Estatus del contrato  \
# Orden de gobierno
# APF                               MXN             Expirado
# GM                                MXN             Expirado
# APF                               MXN             Expirado
# APF                               MXN             Expirado
# APF                               MXN             Expirado
#
#                                 Proveedor o contratista  \
# Orden de gobierno
# APF                         MARCAS NESTLE, S.A. DE C.V.
# GM                 MGR TEXTILES Y CONFECCIONES SA DE CV
# APF                                  MAYDE SOLÍS MÉNDEZ
# APF                          ESTAFETA MEXICANA SA DE CV
# APF                          ESTAFETA MEXICANA SA DE CV
#
#                   Clave del país de la empresa  RFC verificado en el SAT
# Orden de gobierno
# APF                                         MX                         0
# GM                                          MX                         1
# APF                                         MX                         0
# APF                                         MX                         1
# APF                                         MX                         1

# %% [markdown]
# Guardamos el resultado para tener el documento disponible para otras consultas:

# %%
contratos_clean.to_csv('/content/drive/MyDrive/Checkpoint Modulo 3/Contratos2020_clean.csv')

# %% [markdown]
# **Realizamos un análisis exploratorio de los datos**
#
# Ya con nuestro DF limpio podemos hacer ciertas consultas para contestar algunas preguntas.

# %%
tipo_proc = contratos_clean.groupby('Tipo de procedimiento').size()
tipo_proc
# Out:
# Tipo de procedimiento
# ADJUDICACIÓN DIRECTA                    125057
# CONTRATO ENTRE ENTES PUBLICOS              881
# INVITACIÓN A CUANDO MENOS 3 PERSONAS     10825
# LICITACIÓN PÚBLICA                       18963
# OTRAS CONTRATACIONES                      3953
# PROYECTO DE CONVOCATORIA                    47
# dtype: int64

# %% [markdown]
# La consulta size nos hace un conteo de cada uno de los tipos de procedimiento por el cual se llevaron a cabo los contratos de este listado, teniendo como valor más relevante la adjudicación directa con un 78% contra las adjudicaciones por medio de licitación pública con un 12% y las invitaciones a cuando menos 3 de 7%.
#
# Aplicando un análisis de las instituciones que más procedimientos de adjudicación directa llevaron a cabo, generamos el siguiente listado.

# %%
cont_ad = contratos_clean.groupby('Tipo de procedimiento')['Siglas de la Institución'].value_counts()
cont_ad.get('ADJUDICACIÓN DIRECTA').head(10)
# Out:
# Siglas de la Institución
# IMSS         37782
# DICONSA      19473
# ISSSTE        7866
# OnceTV        2716
# CINVESTAV     1968
# INDAABIN      1939
# SEMAR         1609
# INCMNSZ       1564
# CULTURA       1457
# BIENESTAR     1246
# Name: count, dtype: int64

# %% [markdown]
# En la siguiente consulta hacemos una solicitud para conocer el monto de los contratos por tipo de procedimiento y la moneda del contrato.

# %%
m_total = contratos_clean.groupby(['Tipo de procedimiento', 'Moneda del contrato'])['Importe del contrato'].sum()
m_total
# Out:
# Tipo de procedimiento                 Moneda del contrato
# ADJUDICACIÓN DIRECTA                  CAD                    6.821000e+03
#                                       EUR                    6.615832e+07
#                                       GBP                    2.358000e+04
#                                       JPY                    1.230000e+06
#                                       MXN                    1.969854e+11
#                                       USD                    7.196238e+08
# CONTRATO ENTRE ENTES PUBLICOS         MXN                    9.857796e+09
# INVITACIÓN A CUANDO MENOS 3 PERSONAS  MXN                    2.056421e+10
#                                       USD                    6.241764e+06
# LICITACIÓN PÚBLICA                    EUR                    8.929300e+06
#                                       MXN                    2.140225e+11
#                                       USD                    1.204065e+08
# OTRAS CONTRATACIONES                  EUR                    9.315000e+02
#                                       MXN                    5.793818e+10
#                                       USD                    1.185852e+08
# PROYECTO DE CONVOCATORIA              MXN                    6.542016e+08
# Name: Importe del contrato, dtype: float64

# %%
adj_dir = m_total.loc['ADJUDICACIÓN DIRECTA']
adj_dir
# Out:
# Moneda del contrato
# CAD    6.821000e+03
# EUR    6.615832e+07
# GBP    2.358000e+04
# JPY    1.230000e+06
# MXN    1.969854e+11
# USD    7.196238e+08
# Name: Importe del contrato, dtype: float64

# %%
df = pd.DataFrame(adj_dir)
df
# Out:
#                      Importe del contrato
# Moneda del contrato
# CAD                          6.821000e+03
# EUR                          6.615832e+07
# GBP                          2.358000e+04
# JPY                          1.230000e+06
# MXN                          1.969854e+11
# USD                          7.196238e+08

# %% [markdown]
# #**Módulo 4: Análisis de datos con Python**
#
# Sesión 1: Estimados de Locación y Variabilidad
#
# Partiendo del proyecto final del modulo 3, teniendo ya nuestro dataset limpio, procederemos a obtener estimados de locación y variabilidad para describir nuestros datos.

# %% [markdown]
# *Promedio*

# %%
round(contratos_clean['Importe del contrato'].mean(), 2)
# Out:
# np.float64(3137018.55)

# %% [markdown]
# *Mediana*

# %%
contratos_clean['Importe del contrato'].median()
# Out:
# 135069.0

# %% [markdown]
# *Media Truncada*

# %%
from scipy import stats

# %%
round(stats.trim_mean(contratos_clean['Importe del contrato'], 0.1), 2)
# Out:
# np.float64(308150.0)

# %% [markdown]
# *Desviación Estandar*

# %%
round(contratos_clean['Importe del contrato'].std(), 2)
# Out:
# 97758628.04

# %% [markdown]
# *Rango*

# %%
contratos_clean['Importe del contrato'].max() - contratos_clean['Importe del contrato'].min()
# Out:
# 25849460178.0

# %% [markdown]
# *Percentiles*

# %%
print(f'Valor mínimo: {contratos_clean["Importe del contrato"].min()}')
print(f'Percentil 10: {contratos_clean["Importe del contrato"].quantile(0.1)}')
print(f'Percentil 25: {contratos_clean["Importe del contrato"].quantile(0.25)}')
print(f'Percentil 50: {contratos_clean["Importe del contrato"].median()}')
print(f'Percentil 75: {contratos_clean["Importe del contrato"].quantile(0.75)}')
print(f'Percentil 90: {contratos_clean["Importe del contrato"].quantile(0.9)}')
print(f'Valor máximo: {contratos_clean["Importe del contrato"].max()}')
# Out:
# Valor mínimo: 0.0
# Percentil 10: 11759.939999999999
# Percentil 25: 42484.6375
# Percentil 50: 135069.0
# Percentil 75: 489929.73750000005
# Percentil 90: 2247334.49
# Valor máximo: 25849460178.0

# %% [markdown]
# *Rango intercuartílico*

# %%
round(contratos_clean['Importe del contrato'].quantile(0.75) - contratos_clean['Importe del contrato'].quantile(0.25),2)
# Out:
# np.float64(447445.1)

# %% [markdown]
# Los boxplots los podemos utilizar para visualizar la distribución de nuestros valores de acuerdo a la media de los mismos.

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")
sns.boxplot(x=contratos_clean['Importe del contrato'])
# Out:
# <Axes: xlabel='Importe del contrato'>

# %% [markdown]
# Para poder visualizar este análisis de una forma mas acotada, delimitamos los valores atípicos con el rango intercuartílico.

# %%
iqr = contratos_clean['Importe del contrato'].quantile(0.75) - contratos_clean['Importe del contrato'].quantile(0.25)
filtro_inferior = contratos_clean['Importe del contrato'] > contratos_clean['Importe del contrato'].quantile(0.25) - (iqr * 1.5)
filtro_superior = contratos_clean['Importe del contrato'] < contratos_clean['Importe del contrato'].quantile(0.75) + (iqr * 1.5)

df_filtrado = contratos_clean[filtro_inferior & filtro_superior]

# %%
sns.boxplot(df_filtrado['Importe del contrato'])
# Out:
# <Axes: ylabel='Importe del contrato'>

# %% [markdown]
# Tomando en cuenta la amplitud que tenemos en nuestros datos, podemos dividir nuestro conjunto de datos en segmentos.

# %%
importes = contratos_clean['Importe del contrato']

# %%
segmentos = pd.cut(importes, 10)

contratos_clean['Importe del contrato'].groupby(segmentos).count()
# Out:
# /tmp/ipykernel_2642/1918780546.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contratos_clean['Importe del contrato'].groupby(segmentos).count()
# Importe del contrato
# (-25849460.178, 2584946017.8]     159713
# (2584946017.8, 5169892035.6]           7
# (5169892035.6, 7754838053.4]           1
# (7754838053.4, 10339784071.2]          2
# (10339784071.2, 12924730089.0]         0
# (12924730089.0, 15509676106.8]         1
# (15509676106.8, 18094622124.6]         1
# (18094622124.6, 20679568142.4]         0
# (20679568142.4, 23264514160.2]         0
# (23264514160.2, 25849460178.0]         1
# Name: Importe del contrato, dtype: int64

# %% [markdown]
# En este dataset tenemos una clasificación por la cual se establece el tipo de procedimiento por el cual se llevó la adjudicación de un contrato, revisamos estas categorias por medio del método unique.

# %%
contratos_clean['Tipo de procedimiento'].unique()
# Out:
# array(['ADJUDICACIÓN DIRECTA', 'INVITACIÓN A CUANDO MENOS 3 PERSONAS',
#        'LICITACIÓN PÚBLICA', 'OTRAS CONTRATACIONES',
#        'CONTRATO ENTRE ENTES PUBLICOS', 'PROYECTO DE CONVOCATORIA'],
#       dtype=object)

# %%
contratos_clean['Tipo de procedimiento'].nunique()
# Out:
# 6

# %%
contratos_clean['Tipo de procedimiento'].value_counts()
# Out:
# Tipo de procedimiento
# ADJUDICACIÓN DIRECTA                    125057
# LICITACIÓN PÚBLICA                       18963
# INVITACIÓN A CUANDO MENOS 3 PERSONAS     10825
# OTRAS CONTRATACIONES                      3953
# CONTRATO ENTRE ENTES PUBLICOS              881
# PROYECTO DE CONVOCATORIA                    47
# Name: count, dtype: int64

# %% [markdown]
# Con este método podemos conocer la cantidad de procedimientos que se llevaron a cabo de acuerdo a su tipo de adjudicación.

# %%
conteo = contratos_clean['Tipo de procedimiento'].value_counts()

# %%
ax = sns.barplot(conteo.index, conteo)
ax.set_title('Conteo por tipo de procedimiento')
ax.set(ylabel='conteo')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2642/74909839.py in <cell line: 0>()
# ----> 1 ax = sns.barplot(conteo.index, conteo)
#       2 ax.set_title('Conteo por tipo de procedimiento')
#       3 ax.set(ylabel='conteo')
#       4 ax.set_xticklabels(ax.get_xticklabels(), rotation=85);
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# Hacemos una conversión de los valores para presentarlos en porcentaje.

# %%
conteo * 100 / conteo.sum()
# Out:
# Tipo de procedimiento
# ADJUDICACIÓN DIRECTA                    78.294705
# LICITACIÓN PÚBLICA                      11.872206
# INVITACIÓN A CUANDO MENOS 3 PERSONAS     6.777231
# OTRAS CONTRATACIONES                     2.474863
# CONTRATO ENTRE ENTES PUBLICOS            0.551570
# PROYECTO DE CONVOCATORIA                 0.029425
# Name: count, dtype: float64

# %%
en_porc = conteo * 100 / conteo.sum()

# %%
ax = sns.barplot(en_porc.index, en_porc)
ax.set_title('Conteo por tipo de procedimiento')
ax.set(ylabel='conteo')
ax.set_xticklabels(ax.get_xticklabels(), rotation=85);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2642/2295110467.py in <cell line: 0>()
# ----> 1 ax = sns.barplot(en_porc.index, en_porc)
#       2 ax.set_title('Conteo por tipo de procedimiento')
#       3 ax.set(ylabel='conteo')
#       4 ax.set_xticklabels(ax.get_xticklabels(), rotation=85);
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
import plotly.express as px

# %%
df_group = contratos_clean.groupby('Tipo de procedimiento')[['Siglas de la Institución', 'Importe del contrato']].max()

df_group.head()
# Out:
#                                      Siglas de la Institución  \
# Tipo de procedimiento
# ADJUDICACIÓN DIRECTA                                      ZAC
# CONTRATO ENTRE ENTES PUBLICOS                             VER
# INVITACIÓN A CUANDO MENOS 3 PERSONAS                      ZAC
# LICITACIÓN PÚBLICA                                        ZAC
# OTRAS CONTRATACIONES                                      ZAC
#
#                                       Importe del contrato
# Tipo de procedimiento
# ADJUDICACIÓN DIRECTA                          2.584946e+10
# CONTRATO ENTRE ENTES PUBLICOS                 8.111874e+08
# INVITACIÓN A CUANDO MENOS 3 PERSONAS          1.275531e+09
# LICITACIÓN PÚBLICA                            1.599460e+10
# OTRAS CONTRATACIONES                          1.651302e+09

# %%
df_group['count'] = 1

# %%
top_5_importe = df_group['Importe del contrato'].value_counts().head(5)

# %%
top_5_df = df_group[df_group['Importe del contrato'].isin(top_5_importe.index)]

# %%
fig = px.treemap(top_5_df, path=['Siglas de la Institución', 'Importe del contrato'], values='count')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09d8d032-2935-4e67-9ade-c5f4ef23fbfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09d8d032-2935-4e67-9ade-c5f4ef23fbfb")) {                    Plotly.newPlot(                        "09d8d032-2935-4e67-9ade-c5f4ef23fbfb",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["VER\u002f811187449.4","ZAC\u002f1275530658.0","ZAC\u002f1651301947.0","ZAC\u002f15994602016.0","ZAC\u002f25849460178.0","VER","ZAC"],"labels":["811187449.4","1275530658.0","1651301947.0","15994602016.0","25849460178.0","VER","ZAC"],"name":"","parents":["VER","ZAC","ZAC","ZAC","ZAC","",""],"values":[1,1,1,1,1,1,4],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"co ...

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
